# %% [markdown]
# <a href="https://colab.research.google.com/github/AndradeJV/ds-analysis-python/blob/main/Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import files with python

# %% [markdown]
# ## CSV file

# %%
import numpy as np
import pandas as pd
# Out:
# 3.141592653589793

# %%
data = pd.read_csv('/content/drive/MyDrive/Estudos/Python - DS/files/BaseLogística.csv', sep=';', encoding='iso-8859-1')

data.head()
# Out:
#    DataPedido  NoPedido DataPrevistaEntrega DataEmissaoCTE DataEntrega  \
# 0       44050   5764070          11/08/2021     11/08/2021         NaN
# 1       44050   5764069          11/08/2021     11/08/2021         NaN
# 2       44054   5765934          15/08/2021     17/08/2021         NaN
# 3       44054   5765935          15/08/2021     17/08/2021         NaN
# 4       44055   5766151          16/08/2021     17/08/2021         NaN
#
#    cdRepresentante Representante   Equipe  cdCliente       Cliente  \
# 0             3825       BNU-CEN     VALE     177170  Cliente 8517
# 1             3825       BNU-CEN     VALE     177170  Cliente 8517
# 2              839           BRU  LITORAL     174918  Cliente 5089
# 3              839           BRU  LITORAL     174918  Cliente 5089
# 4             3522       ITJ-CTR  LITORAL      50735  Cliente 6207
#
#                 CanalAtendimento  cdCidade   Cidade  OcorrenciaDevolucao
# ...

# %%
print(f'My table countains: {data.shape}')
# Out:
# My table countains: (243343, 14)

# %% [markdown]
# ### Rename columns

# %%
data.head()
# Out:
#    DataPedido  NoPedido DataPrevistaEntrega DataEmissaoCTE DataEntrega  \
# 0       44050   5764070          11/08/2021     11/08/2021         NaN
# 1       44050   5764069          11/08/2021     11/08/2021         NaN
# 2       44054   5765934          15/08/2021     17/08/2021         NaN
# 3       44054   5765935          15/08/2021     17/08/2021         NaN
# 4       44055   5766151          16/08/2021     17/08/2021         NaN
#
#    cdRepresentante Representante   Equipe  cdCliente       Cliente  \
# 0             3825       BNU-CEN     VALE     177170  Cliente 8517
# 1             3825       BNU-CEN     VALE     177170  Cliente 8517
# 2              839           BRU  LITORAL     174918  Cliente 5089
# 3              839           BRU  LITORAL     174918  Cliente 5089
# 4             3522       ITJ-CTR  LITORAL      50735  Cliente 6207
#
#                 CanalAtendimento  cdCidade   Cidade  OcorrenciaDevolucao
# ...

# %%
data.rename(columns={'cdCidade': 'codigoCidade'}, inplace=True)
# Out:
# <ipython-input-34-cedf689a0b0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.head().rename(columns={'cdCidade': 'codigoCidade'}, inplace=True)
#         DataPedido  NoPedido DataPrevistaEntrega DataEmissaoCTE DataEntrega  \
# 0            44050   5764070          11/08/2021     11/08/2021         NaN
# 1            44050   5764069          11/08/2021     11/08/2021         NaN
# 2            44054   5765934          15/08/2021     17/08/2021         NaN
# 3            44054   5765935          15/08/2021     17/08/2021         NaN
# 4            44055   5766151          16/08/2021     17/08/2021         NaN
# ...            ...       ...                 ...            ...         ...
# 243338       43475   5415635          13/01/2019     10/01/2019  11/01/2019
# ...

# %% [markdown]
# ### Deleting columns

# %%
data_adjust = data.drop(columns={'DataPedido'})


data_adjust.head()
# Out:
#    NoPedido DataPrevistaEntrega DataEmissaoCTE DataEntrega  cdRepresentante  \
# 0   5764070          11/08/2021     11/08/2021         NaN             3825
# 1   5764069          11/08/2021     11/08/2021         NaN             3825
# 2   5765934          15/08/2021     17/08/2021         NaN              839
# 3   5765935          15/08/2021     17/08/2021         NaN              839
# 4   5766151          16/08/2021     17/08/2021         NaN             3522
#
#   Representante   Equipe  cdCliente       Cliente  \
# 0       BNU-CEN     VALE     177170  Cliente 8517
# 1       BNU-CEN     VALE     177170  Cliente 8517
# 2           BRU  LITORAL     174918  Cliente 5089
# 3           BRU  LITORAL     174918  Cliente 5089
# 4       ITJ-CTR  LITORAL      50735  Cliente 6207
#
#                 CanalAtendimento  codigoCidade   Cidade  OcorrenciaDevolucao
# 0  LOJA DE BRINQUEDOS/ELETRONICO          64.0   ILHOTA                    0
# ...

# %% [markdown]
# ## XLSX file

# %%
data_excel = pd.read_excel('/content/drive/MyDrive/Estudos/Python - DS/files/Base_RH.xlsx')


data_excel.head()
# Out:
#     ID           Nome Completo Genero Data de Nascimento  \
# 0  195         Adelino Werneck      M         1997-04-27
# 1  102        Adriano de Souza      M         1993-12-09
# 2  342  Alfredo Machado Araujo      M         1986-08-14
# 3  320          Aline da Silva      F         1976-06-22
# 4   88          Aline de Souza      F         1981-09-04
#
#                                             Endereço  Salario        Cargo  \
# 0  Av. Borges de Medeiros, 3120 - Praia de Belas,...    11566  Coordenador
# 1  R. Brasílio Itiberê, 3279 - Água Verde, Curiti...     1459   Estagiário
# 2  R. Dr. Antônio Castro Prado, 422 - Vila Rossi ...     9958  Coordenador
# 3  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...      801   Estagiário
# 4  Shopping Barra - Av. Centenário, 2992 - Barra,...    16855      Gerente
#
#              Área
# 0  Administrativo
# 1       Comercial
# 2  Administrativo
# 3       Operações
# 4  Administrativo

# %% [markdown]
# ### Updating creating new values

# %%
data_adjust = data_excel


data_adjust['Salario'] = data_adjust['Salario'] + 1000


data_adjust.head()
# Out:
#     ID           Nome Completo Genero Data de Nascimento  \
# 0  195         Adelino Werneck      M         1997-04-27
# 1  102        Adriano de Souza      M         1993-12-09
# 2  342  Alfredo Machado Araujo      M         1986-08-14
# 3  320          Aline da Silva      F         1976-06-22
# 4   88          Aline de Souza      F         1981-09-04
#
#                                             Endereço  Salario        Cargo  \
# 0  Av. Borges de Medeiros, 3120 - Praia de Belas,...    12566  Coordenador
# 1  R. Brasílio Itiberê, 3279 - Água Verde, Curiti...     2459   Estagiário
# 2  R. Dr. Antônio Castro Prado, 422 - Vila Rossi ...    10958  Coordenador
# 3  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...     1801   Estagiário
# 4  Shopping Barra - Av. Centenário, 2992 - Barra,...    17855      Gerente
#
#              Área
# 0  Administrativo
# 1       Comercial
# 2  Administrativo
# 3       Operações
# 4  Administrativo

# %%
data_excel['Salario Reajustado'] = data_excel['Salario'] * 1.1


data_excel
# Out:
#       ID               Nome Completo Genero Data de Nascimento  \
# 0    195             Adelino Werneck      M         1997-04-27
# 1    102            Adriano de Souza      M         1993-12-09
# 2    342      Alfredo Machado Araujo      M         1986-08-14
# 3    320              Aline da Silva      F         1976-06-22
# 4     88              Aline de Souza      F         1981-09-04
# ..   ...                         ...    ...                ...
# 229  439   Vitor Almeida da Silveira      M         1984-03-23
# 230   34  Vitor Cordovil de Maglhães      M         1995-07-23
# 231  464     Wesley de Melo Teixeira      M         1997-11-21
# 232  514               Yago Oliveira      M         1982-08-31
# 233  163    Yasmini de Almeida Richa      F         1979-02-25
#
#                                               Endereço  Salario        Cargo  \
# 0    Av. Borges de Medeiros, 3120 - Praia de Belas,...    12566  Coordenador
# ...

# %% [markdown]
# ### Math functions

# %%
sum(data_excel['Salario'])
# Out:
# 1984151.4

# %%
data_excel.Salario.mean().round(2)
# Out:
# 7708.44

# %%
max(data_excel.Salario)
min(data_excel.Salario)
# Out:
# 1801

# %%
biggest_salary = max(data_excel.Salario)

line = data_excel.loc[data_excel.Salario == biggest_salary]

line
# Out:
#      ID   Nome Completo Genero Data de Nascimento  \
# 86  330  Gabriela Costa      F         1989-07-13
#
#                                              Endereço  Salario    Cargo Área  \
# 86  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...    26340  Diretor   RH
#
#     Salario Reajustado
# 86             28974.0

# %% [markdown]
# ### Counter

# %%
data_excel['Área'].value_counts()

data_excel['Cargo'].value_counts()
# Out:
# Estagiário     82
# Analista       78
# Coordenador    53
# Gerente        20
# Diretor         1
# Name: Cargo, dtype: int64

# %%
data_excel.query('Genero == "F"')['Área'].value_counts()
# Out:
# Comercial         30
# Administrativo    27
# Operações         18
# Financeiro        18
# Logística         16
# RH                 5
# Name: Área, dtype: int64

# %%
result_mean = sum(data_excel.Salario) / data_excel.shape[0]

result_mean
# Out:
# 7708.4358974358975
